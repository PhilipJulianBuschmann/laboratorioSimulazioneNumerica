# %% [markdown]
# # <span style="color:green"> Numerical Simulation Laboratory (NSL) </span>
# ## <span style="color:blue">  Numerical exercises 2</span>

# %% [markdown]
# ### Exercise 02.1
# - Compute the following 1D integral via Monte Carlo
# $$I = \int_0^1 \frac{\pi}{2}\cos(\pi x/2) dx = 1$$

# %% [markdown]
# 1. sampling a uniform distribution in $[0,1]$
# 2. using importance sampling (i.e. sampling a non-uniform probability in $[0,1]$)
# conviene usare accept-reject invece che invertire la cumulativa
#
#
# <span style="color:red">Show a picture of both your estimations of $I$</span> and their uncertainties with a large number of *throws* $M$ (e.g. $M\ge 10^4$) as a function of the number of blocks, $N$</font>.

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

mean, meanerr = np.loadtxt("2.1/OutputMedia.txt", unpack = True);

M=500000              # Total number of throws
N=100                 # Number of blocks
L=int(M/N)            # Number of throws in each block, please use for M a multiple of N
x = np.arange(N)      # [0,1,2,...,N-1]

x*=L
plt.errorbar(x,mean -1,yerr=meanerr)
plt.xlabel('#throws')
plt.ylabel('Int - 1')
plt.grid(True)
plt.title('Integral with Uniform Distribution Sampling\nM=5*10^5')
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

mean, meanerr = np.loadtxt("2.1/OutputAR.txt", unpack = True);


M=500000              # Total number of throws
N=100                 # Number of blocks
L=int(M/N)            # Number of throws in each block, please use for M a multiple of N
x = np.arange(N)      # [0,1,2,...,N-1]

x*=L
plt.errorbar(x,mean - 1,yerr=meanerr)
plt.xlabel('#throws')
plt.ylabel('Int - 1')
plt.grid(True)
plt.title('Integral with Importance Sampling Method\nusing $f(x)=2(1-x)$\nM=5*10^5')
plt.show()

# %% [markdown]
# ***Come mi aspettavo l'importance sampling porta una precisione maggiore, circa 5/10 volte***

# %% [markdown]
# ### Exercise 02.2
# - <span style="color:red">3D Random Walks (RW) on a cubic lattice and in the continuum:</span> Repeat many times (e.g. say $10^4$) the simulation of a random walk in 3D always starting at the origin

# %% [markdown]
# 1. on a cubic lattice with lattice constant $a=1$; at each discrete time the walker makes a forward or backward step of length equal to $a$ in one of the 3 principal directions of the lattice: $x$, $y$ or $z$
# 2. in the continuum; at each discrete time the walker makes a step of length equal to $a(=1)$ along a **random direction** obtained by sampling **uniformly** the solid angle: $\theta \in [0,\pi]$ and $\phi \in [0,2\pi]$
#
# **mediare tra tutti i RW per ognuno dei 100 passi, con incertezze. Conviene dividere in 100 blocchi, valuto la media per ognuno, faccio il valore medio tra i blocchi e la dev standard.**
#
# <span style="color:red">Show a picture of $\sqrt{\langle |\vec{r}_N|^2 \rangle_{RW}}$ for both RWs</span>, with their statistical uncertainties, as function of the step $i\in [0,10^2]$.
#
# Suggestion: divide your $M$ throws into a reasonable number of blocks, compute $\sqrt{\langle |\vec{r}_N|^2 \rangle_{RW}}$ as function of the step $i\in [0,10^2]$ in each block and use these values (for fixed $i$) to obtain the average value and its statistical uncertainty.
#
# Note that you could try to fit both results with a function like $f(N)=k\sqrt{N}$. Do your results indicate a diffusive behavior?

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

mean, meanerr = np.loadtxt("2.2/Lattice.txt", unpack = True);

M=100000              # Total number of throws
N=100                 # Number of blocks
L=int(M/N)            # Number of throws in each block, please use for M a multiple of N
x = np.arange(N)      # [0,1,2,...,N-1]

x*=L
plt.errorbar(x,mean,yerr=meanerr, label = 'Data')
plt.xlabel('#throws')
plt.ylabel('Distance')
plt.grid(True)
t = np.linspace(0, 100000, 1000)
sig = 0.025*np.sqrt(t) + 1
plt.plot(t, sig, linewidth=1, label='k*sqrt(x) + 1')
plt.legend(loc='right')
plt.title('3D Lattice Random Walk Simulation\nM=10^4')
plt.show()

# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import math

mean, meanerr = np.loadtxt("2.2/Free.txt", unpack = True);

M=100000              # Total number of throws
N=100                 # Number of blocks
L=int(M/N)            # Number of throws in each block, please use for M a multiple of N
x = np.arange(N)      # [0,1,2,...,N-1]

x*=L
plt.errorbar(x,mean,yerr=meanerr, label = 'Data')
plt.xlabel('#throws')
plt.ylabel('Distance')
plt.grid(True)
t = np.linspace(0, 100000, 1000)
sig = 0.025*np.sqrt(t) + 1
plt.plot(t, sig, linewidth=1, label='k*sqrt(x) + 1')
plt.legend(loc='right')
plt.title('3D Free Random Walk Simulation\nM=10^4')
plt.show()
